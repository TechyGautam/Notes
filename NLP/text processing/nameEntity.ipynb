# %%
para = "Elon Musk visited India and met Prime Minister Narendra Modi in New Delhi."
print(para)
# Out:
# Elon Musk visited India and met Prime Minister Narendra Modi in New Delhi.

# %%
import nltk
words = nltk.word_tokenize(para)
tag_element = nltk.pos_tag(words)
nltk.ne_chunk(tag_element).draw()
